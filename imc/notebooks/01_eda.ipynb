# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "mustafaali96/weight-height",
  "weight-height.csv",
)
# Out:
# c:\Users\LowCost\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.4.0) or chardet (7.4.3)/charset_normalizer (3.4.2) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# # EDA - Análise Exploratória

# %%
print(df.head())
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ## Estatísticas descritivas

# %%
print(df.describe())
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  str
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), str(1)
# memory usage: 283.3 KB
# None

# %%
print(df['Gender'].value_counts())
print("\n", df['Height'].value_counts())
print("\n", df['Weight'].value_counts())
# Out:
# Gender
# Male      5000
# Female    5000
# Name: count, dtype: int64
#
#  Height
# 73.847017    1
# 68.781904    1
# 74.110105    1
# 71.730978    1
# 69.881796    1
#             ..
# 66.172652    1
# 67.067155    1
# 63.867992    1
# 69.034243    1
# 61.944246    1
# Name: count, Length: 10000, dtype: int64
#
#  Weight
# 241.893563    1
# 162.310473    1
# 212.740856    1
# 220.042470    1
# 206.349801    1
#              ..
# 136.777454    1
# 170.867906    1
# 128.475319    1
# 163.852461    1
# 113.649103    1
# Name: count, Length: 10000, dtype: int64

# %%
df_man = df[df['Gender'] == 'Male']  
print(df_man.describe()) 

df_female = df[df['Gender'] == 'Female']  
print("\n", df_female.describe())
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean     69.026346   187.020621
# std       2.863362    19.781155
# min      58.406905   112.902939
# 25%      67.174679   173.887767
# 50%      69.027709   187.033546
# 75%      70.988744   200.357802
# max      78.998742   269.989699
#
#              Height       Weight
# count  5000.000000  5000.000000
# mean     63.708774   135.860093
# std       2.696284    19.022468
# min      54.263133    64.700127
# 25%      61.894441   122.934096
# 50%      63.730924   136.117583
# 75%      65.563565   148.810926
# max      73.389586   202.237214

# %%
df.to_csv(r"..\data\data_frame_kaggle.csv", index=False)
